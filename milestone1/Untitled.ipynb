# %%
import yaml
from yaml.loader import SafeLoader
from datetime import datetime 
import time
import threading
 
a_yaml_file = open("Milestone1B.yaml")
workflow= yaml.load(a_yaml_file, Loader=yaml.SafeLoader)

file = open("log2.txt","w")
threads= []
def flow(ob, execution, activities):
    if execution == "Sequential":
        for n in activities:
            now = datetime.now()
            file.write(f"{now};{ob}.{n} Entry\n")
            if activities[n]['Type'] == "Flow":
                newwork = ob + '.' + n
                flow(newwork,activities[n]['Execution'],activities[n]['Activities'])
            elif activities[n]['Type'] == "Task":
                newwork = ob + '.' + n
                task(newwork,activities[n]['Function'],activities[n]['Inputs'])
            now= datetime.now()
            file.write(f"{now};{ob}.{n} Exit\n")
    if execution == "Concurrent":
        for n in activities:
            now = datetime.now()
            file.write(f"{now};{ob}.{n} Entry\n")
            if activities[n]['Type'] == "Flow":
                newobj = ob + '.' + n 
                thread = threading.Thread(target=flow,args=[newwork,activities[n]['Execution'],activities[n]['Activities']])
                thread.start()
                thread.append({thread,newwork})
            elif  activities[n]['Type'] == "Task":
                newwork = ob + '.' + n
                thread = threading.Thread(target=task,args=[newwork,activities[n]['Function'],activities[n]['Inputs']])  
                thread.start()
                thread.append({thread,newwork}) 
            now = datetime.now()
            for thread in threads:
                thread.join()
            file.write(f"{now};{ob}.{n} Exit\n")
def task(ob,function,inputs):
        if function == 'TimeFunction':
            fun_input = inputs['FunctionInput']  
            exc_time =inputs['ExecutionTime']
        now = datetime.now()
        file.write(f"{now};{ob} Executing {function} ({fun_input}), {exc_time})\n")
        time.sleep(int(exc_time))
for ob in workflow:
        now = datetime.now()
        file.write(F"{now};{ob} Entry\n")
        if workflow[ob]['Type'] == "Flow":
            flow(ob,workflow[ob]['Execution'],workflow[ob]['Activities'])
        elif workflow[ob]['Type'] == "Task":
            task(ob,workflow[ob]['function'],workflow[ob]['Inputs'])   
        now = datetime.now()
        file.write(f"{now};{ob} Exit")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-5278e1e0421f> in <module>
#      52         file.write(F"{now};{ob} Entry\n")
#      53         if workflow[ob]['Type'] == "Flow":
# ---> 54             flow(ob,workflow[ob]['Execution'],workflow[ob]['Activities'])
#      55         elif workflow[ob]['Type'] == "Task":
#      56             task(ob,workflow[ob]['function'],workflow[ob]['Inputs'])
#
# <ipython-input-57-5278e1e0421f> in flow(ob, execution, activities)
#      17             if activities[n]['Type'] == "Flow":
#      18                 newwork = ob + '.' + n
# ---> 19                 flow(newwork,activities[n]['Execution'],activities[n]['Activities'])
#      20             elif activities[n]['Type'] == "Task":
#      21                 newwork = ob + '.' + n
#
# <ipython-input-57-5278e1e0421f> in flow(ob, execution, activities)
#      36                 thread = threading.Thread(target=task,args=[newwork,activities[n]['Function'],activities[n]['Inputs']])
#      37                 thread.start()
# ---> 38                 thread.append({thread,newwork})
#      39             now = datetime.now()
#      40             for thread in threads:
#
# AttributeError: 'Thread' object has no attribute 'append'

# %%
import yaml
from yaml.loader import SafeLoader
from datetime import datetime 
import time
import threading
 
a_yaml_file = open("Milestone1A.yaml")
workflow= yaml.load(a_yaml_file, Loader=yaml.SafeLoader)

file = open("log1.txt","w")
threads= []
def flow(ob, execution, activities):
    if execution == "Sequential":
        for n in activities:
            now = datetime.now()
            file.write(f"{now};{ob}.{n} Entry\n")
            if activities[n]['Type'] == "Flow":
                newwork = ob + '.' + n
                flow(newwork,activities[n]['Execution'],activities[n]['Activities'])
            elif activities[n]['Type'] == "Task":
                newwork = ob + '.' + n
                task(newwork,activities[n]['Function'],activities[n]['Inputs'])
            now= datetime.now()
            file.write(f"{now};{ob}.{n} Exit\n")
def task(ob,function,inputs):
        if function == 'TimeFunction':
            fun_input = inputs['FunctionInput']  
            exc_time =inputs['ExecutionTime']
        now = datetime.now()
        file.write(f"{now};{ob} Executing {function} ({fun_input}), {exc_time})\n")
        time.sleep(int(exc_time))
for ob in workflow:
        now = datetime.now()
        file.write(F"{now};{ob} Entry\n")
        if workflow[ob]['Type'] == "Flow":
            flow(ob,workflow[ob]['Execution'],workflow[ob]['Activities'])
        elif workflow[ob]['Type'] == "Task":
            task(ob,workflow[ob]['function'],workflow[ob]['Inputs'])   
        now = datetime.now()
        file.write(f"{now};{ob} Exit")
